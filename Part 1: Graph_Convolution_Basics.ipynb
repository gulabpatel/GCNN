# %% [markdown]
# Blog post: [Gpaph Conv Basics](https://towardsdatascience.com/how-to-do-deep-learning-on-graphs-with-graph-convolutional-networks-7d2250723780)

# %%
# Install RDKit, Takes 2-3 minutes
# !wget -c https://repo.continuum.io/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !chmod +x Miniconda3-latest-Linux-x86_64.sh
# !time bash ./Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local
# !conda install -y -c deepchem -c rdkit -c conda-forge -c omnia deepchem-gpu=2.3.0 python=3.6
# Out:
# --2021-01-12 17:40:14--  https://repo.continuum.io/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.continuum.io (repo.continuum.io)... 104.18.200.79, 104.18.201.79, 2606:4700::6812:c94f, ...
# Connecting to repo.continuum.io (repo.continuum.io)|104.18.200.79|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh [following]
# --2021-01-12 17:40:14--  https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 416 Requested Range Not Satisfiable
#
#     The file is already fully retrieved; nothing to do.
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# failed with initial frozen solve. Retrying with flexible solve.
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# failed with initial frozen solve. Retrying with flexible solve.
# \
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# failed
#
# UnsatisfiableError: The following specifications were found to be incompatible with each other:
#
# Output in format: Requested package -> Available versions
#
# Package cffi conflicts for:
# brotlipy==0.7.0=py38h27cfd23_1003 -> cffi[version='>=1.0.0']
# cffi==1.14.3=py38h261ae71_2
# urllib3==1.25.11=py_0 -> brotlipy[version='>=0.6.0'] -> cffi[version='!=1.11.3,>=1.8|>=1.0.0']
# pyopenssl==19.1.0=pyhd3eb1b0_1 -> cryptography[version='>=2.8'] -> cffi[version='!=1.11.3,>=1.8']
# argon2-cffi -> cffi[version='>=1.0.0']
# cryptography==3.2.1=py38h3c74f83_1 -> cffi[version='!=1.11.3,>=1.8']
# notebook -> argon2-cffi -> cffi[version='>=1.0.0']
#
# Package c-ares conflicts for:
# tensorflow-estimator -> grpcio[version='>=1.8.6'] -> c-ares[version='>=1.16.1,<2.0a0']
# tensorflow-base -> grpcio[version='>=1.8.6'] -> c-ares[version='>=1.16.1,<2.0a0']
# libnghttp2 -> c-ares[version='>=1.16.1,<2.0a0|>=1.7.5']
# libcurl -> libnghttp2[version='>=1.41.0,<2.0a0'] -> c-ares[version='>=1.16.1,<2.0a0|>=1.7.5']
# c-ares
# grpcio -> c-ares[version='>=1.16.1,<2.0a0']
#
# Package libffi conflicts for:
# ipywidgets -> python -> libffi[version='>=3.3,<3.4.0a0']
# pyparsing -> python -> libffi[version='>=3.3,<3.4.0a0']
# tornado -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# py-boost -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# prompt-toolkit -> python[version='>=3.6'] -> libffi[version='>=3.3,<3.4.0a0']
# typing_extensions -> python[version='>=3.5'] -> libffi[version='>=3.3,<3.4.0a0']
# joblib -> python[version='>=3.6'] -> libffi[version='>=3.3,<3.4.0a0']
# mdtraj -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# wheel==0.35.1=pyhd3eb1b0_0 -> python -> libffi[version='>=3.3,<3.4.0a0']
# parso -> python[version='>=3.6'] -> libffi[version='>=3.3,<3.4.0a0']
# webencodings -> python -> libffi[version='>=3.3,<3.4.0a0']
# send2trash -> python -> libffi[version='>=3.3,<3.4.0a0']
# cycler -> python -> libffi[version='>=3.3,<3.4.0a0']
# zipp -> python[version='>=3.6'] -> libffi[version='>=3.3,<3.4.0a0']
# jsonschema -> python[version='>=3.6'] -> libffi[version='>=3.3,<3.4.0a0']
# gstreamer -> glib[version='>=2.66.1,<3.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# kiwisolver -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# python-dateutil -> python -> libffi[version='>=3.3,<3.4.0a0']
# werkzeug -> python -> libffi[version='>=3.3,<3.4.0a0']
# pexpect -> python -> libffi[version='>=3.3,<3.4.0a0']
# grpcio -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# keras-applications -> python -> libffi[version='>=3.3,<3.4.0a0']
# numpy -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# six==1.15.0=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# ipython -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# jinja2 -> python -> libffi[version='>=3.3,<3.4.0a0']
# conda==4.9.2=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# astor -> python -> libffi[version='>=3.3,<3.4.0a0']
# idna==2.10=py_0 -> python -> libffi[version='>=3.3,<3.4.0a0']
# simdna -> python -> libffi[version='>=3.3,<3.4.0a0']
# dbus -> glib[version='>=2.58.3,<3.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# glib -> libffi[version='>=3.3,<3.4.0a0']
# argon2-cffi -> cffi[version='>=1.0.0'] -> libffi[version='>=3.3,<3.4.0a0']
# threadpoolctl -> python[version='>=3.5'] -> libffi[version='>=3.3,<3.4.0a0']
# pyzmq -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# markdown -> python -> libffi[version='>=3.3,<3.4.0a0']
# widgetsnbextension -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# pandocfilters -> python -> libffi[version='>=3.3,<3.4.0a0']
# pillow -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# testpath -> python -> libffi[version='>=3.3,<3.4.0a0']
# pytables -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# nbclient -> python[version='>=3.6'] -> libffi[version='>=3.3,<3.4.0a0']
# gast -> python -> libffi[version='>=3.3,<3.4.0a0']
# pysocks==1.7.1=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# setuptools==50.3.1=py38h06a4308_1 -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# jedi -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# libffi==3.3=he6710b0_2
# async_generator -> python[version='>2.7'] -> libffi[version='>=3.3,<3.4.0a0']
# networkx -> python[version='>=3.6'] -> libffi[version='>=3.3,<3.4.0a0']
# python_abi -> python=3.6 -> libffi[version='>=3.3,<3.4.0a0']
# cached-property -> python -> libffi[version='>=3.3,<3.4.0a0']
# pip==20.2.4=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# termcolor -> python -> libffi[version='>=3.3,<3.4.0a0']
# nest-asyncio -> python[version='>=3.5'] -> libffi[version='>=3.3,<3.4.0a0']
# tensorflow-base -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# py-xgboost -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# pandas -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# wrapt -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# pdbfixer -> python -> libffi[version='>=3.3,<3.4.0a0']
# openmm -> python=3.6 -> libffi[version='>=3.3,<3.4.0a0']
# jupyter_client -> python[version='>=3.5'] -> libffi[version='>=3.3,<3.4.0a0']
# pyopenssl==19.1.0=pyhd3eb1b0_1 -> python -> libffi[version='>=3.3,<3.4.0a0']
# notebook -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# jupyterlab_widgets -> python[version='>=3.6'] -> libffi[version='>=3.3,<3.4.0a0']
# google-pasta -> python -> libffi[version='>=3.3,<3.4.0a0']
# pickleshare -> python[version='>=3'] -> libffi[version='>=3.3,<3.4.0a0']
# entrypoints -> python[version='>=3.6'] -> libffi[version='>=3.3,<3.4.0a0']
# cffi==1.14.3=py38h261ae71_2 -> libffi[version='>=3.3,<3.4.0a0']
# decorator -> python -> libffi[version='>=3.3,<3.4.0a0']
# bleach -> python -> libffi[version='>=3.3,<3.4.0a0']
# nbconvert -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# brotlipy==0.7.0=py38h27cfd23_1003 -> cffi[version='>=1.0.0'] -> libffi[version='>=3.3,<3.4.0a0']
# urllib3==1.25.11=py_0 -> python[version='<4.0'] -> libffi[version='>=3.3,<3.4.0a0']
# ipykernel -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# olefile -> python -> libffi[version='>=3.3,<3.4.0a0']
# tensorflow-estimator -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# attrs -> python -> libffi[version='>=3.3,<3.4.0a0']
# backports.functools_lru_cache -> python -> libffi[version='>=3.3,<3.4.0a0']
# python==3.8.5=h7579374_1 -> libffi[version='>=3.3,<3.4.0a0']
# wcwidth -> python -> libffi[version='>=3.3,<3.4.0a0']
# traitlets -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# xgboost -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# backcall -> python -> libffi[version='>=3.3,<3.4.0a0']
# rdkit -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# backports -> python -> libffi[version='>=3.3,<3.4.0a0']
# conda-package-handling==1.7.2=py38h03888b9_0 -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# pycparser==2.20=py_2 -> python -> libffi[version='>=3.3,<3.4.0a0']
# terminado -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# ptyprocess -> python -> libffi[version='>=3.3,<3.4.0a0']
# tqdm==4.51.0=pyhd3eb1b0_0 -> python -> libffi[version='>=3.3,<3.4.0a0']
# pycosat==0.6.3=py38h7b6447c_1 -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# pytz -> python[version='>=3'] -> libffi[version='>=3.3,<3.4.0a0']
# importlib-metadata -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# jupyter_core -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# scipy -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# gst-plugins-base -> glib[version='>=2.56.1,<3.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# prometheus_client -> python -> libffi[version='>=3.3,<3.4.0a0']
# markupsafe -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# requests==2.24.0=py_0 -> python -> libffi[version='>=3.3,<3.4.0a0']
# absl-py -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# certifi==2020.6.20=pyhd3eb1b0_3 -> python -> libffi[version='>=3.3,<3.4.0a0']
# deepchem-gpu -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# matplotlib-base -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# qtpy -> python -> libffi[version='>=3.3,<3.4.0a0']
# nbformat -> python[version='>=3.5'] -> libffi[version='>=3.3,<3.4.0a0']
# sip -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# ruamel_yaml==0.15.87=py38h7b6447c_1 -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# keras-preprocessing -> python -> libffi[version='>=3.3,<3.4.0a0']
# cryptography==3.2.1=py38h3c74f83_1 -> cffi[version='!=1.11.3,>=1.8'] -> libffi[version='>=3.3,<3.4.0a0']
# jupyterlab_pygments -> python -> libffi[version='>=3.3,<3.4.0a0']
# scikit-learn -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# matplotlib -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# pygments -> python[version='>=3.5'] -> libffi[version='>=3.3,<3.4.0a0']
# defusedxml -> python -> libffi[version='>=3.3,<3.4.0a0']
# tensorboard -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# jupyter -> python -> libffi[version='>=3.3,<3.4.0a0']
# qtconsole -> python[version='>=3.6'] -> libffi[version='>=3.3,<3.4.0a0']
# pyrsistent -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# numexpr -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# chardet==3.0.4=py38h06a4308_1003 -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# qt -> glib[version='>=2.56.2,<3.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# mock -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# h5py -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# ipython_genutils -> python -> libffi[version='>=3.3,<3.4.0a0']
# cython -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# pyqt -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# packaging -> python[version='>=2.7'] -> libffi[version='>=3.3,<3.4.0a0']
# jupyter_console -> python[version='>=3.6'] -> libffi[version='>=3.3,<3.4.0a0']
# cairo -> glib[version='>=2.58.3,<3.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
# mistune -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='>=3.3,<3.4.0a0']
#
# Package rdkit conflicts for:
# rdkit
# deepchem-gpu -> rdkit
#
# Package python conflicts for:
# jupyterlab_pygments -> python
# importlib-metadata -> python_abi=3.6[build=*_cp36m] -> python[version='3.6.*|>=3.5|>=3.6']
# xgboost -> python_abi=3.6[build=*_cp36m] -> python=3.6
# tensorflow-base -> python[version='>=3.6,<3.7.0a0']
# tensorflow-base -> astor[version='>=0.6.0'] -> python[version='3.6.*|>=3.8,<3.9.0a0']
# pytz -> python[version='>=3']
# matplotlib -> python_abi=3.6[build=*_cp36m] -> python=3.6
# conda==4.9.2=py38h06a4308_0 -> conda-package-handling[version='>=1.3.0'] -> python[version='>=3.6,<3.7.0a0']
# nbformat -> ipython_genutils -> python[version='>=3.6|>=3.6,<3.7.0a0']
# jupyter_console -> python[version='>=3.6']
# argon2-cffi -> python[version='>=3.6,<3.7.0a0']
# simdna -> matplotlib -> python[version='>=3.6,<3.7.0a0|>=3.8,<3.9.0a0']
# bleach -> packaging -> python[version='>=2.7|>=3.8,<3.9.0a0|>=3.6,<3.7.0a0']
# olefile -> python
# urllib3==1.25.11=py_0 -> python[version='<4.0']
# absl-py -> python_abi=3.6[build=*_cp36m] -> python[version='3.6.*|>=3.8,<3.9.0a0']
# cython -> python_abi=3.6[build=*_cp36m] -> python=3.6
# pickleshare -> python[version='>=3']
# keras-applications -> python
# networkx -> decorator[version='>=4.3.0'] -> python[version='>=3.6,<3.7.0a0|>=3.8,<3.9.0a0']
# prompt-toolkit -> python[version='>=3.6']
# google-pasta -> six -> python[version='>=3.8,<3.9.0a0']
# joblib -> setuptools -> python[version='>=3.6,<3.7.0a0|>=3.8,<3.9.0a0']
# tornado -> python[version='>=3.6,<3.7.0a0']
# pyparsing -> python
# jupyter -> ipykernel -> python[version='>=3.6|>=3.6,<3.7.0a0']
# termcolor -> python
# traitlets -> python[version='>=3.6,<3.7.0a0']
# terminado -> python[version='>=3.6,<3.7.0a0']
# jinja2 -> markupsafe[version='>=0.23'] -> python[version='>=3.6,<3.7.0a0|>=3.8,<3.9.0a0']
# grpcio -> python_abi=3.6[build=*_cp36m] -> python[version='3.6.*|>=3.8,<3.9.0a0']
# send2trash -> python
# webencodings -> python
# chardet==3.0.4=py38h06a4308_1003 -> python[version='>=3.8,<3.9.0a0']
# jupyter_client -> python[version='>=3.5']
# packaging -> python[version='>=2.7']
# jupyter_console -> ipykernel -> python[version='>=3.5|>=3.6,<3.7.0a0']
# pyrsistent -> python[version='>=3.6,<3.7.0a0']
# h5py -> python[version='>=3.6,<3.7.0a0']
# mock -> python[version='>=3.6,<3.7.0a0']
# wrapt -> python[version='>=3.6,<3.7.0a0']
# mdtraj -> python[version='>=3.6,<3.7.0a0']
# python-dateutil -> six -> python[version='>=3.8,<3.9.0a0']
# keras-preprocessing -> python
# prompt-toolkit -> pygments -> python[version='>=3.5']
# ipywidgets -> python
# idna==2.10=py_0 -> python
# markdown -> python
# jupyterlab_pygments -> pygments[version='>=2.4.1,<3'] -> python[version='>=3.5']
# cryptography==3.2.1=py38h3c74f83_1 -> cffi[version='!=1.11.3,>=1.8'] -> python[version='>=3.6,<3.7.0a0']
# nbclient -> async_generator -> python[version='>2.7|>=3.5|>=3.6,<3.7.0a0']
# ptyprocess -> python
# ipywidgets -> ipykernel[version='>=4.5.1'] -> python[version='>=3.5|>=3.6|>=3.6,<3.7.0a0']
# ipython -> python[version='>=3.6,<3.7.0a0']
# jsonschema -> attrs[version='>=17.4.0'] -> python[version='>=3.6,<3.7.0a0|>=3.8,<3.9.0a0']
# traitlets -> decorator -> python[version='3.6.*|>=3.8,<3.9.0a0']
# numpy -> python_abi=3.6[build=*_cp36m] -> python=3.6
# jupyter -> python
# kiwisolver -> python[version='>=3.6,<3.7.0a0']
# jinja2 -> python
# ipykernel -> python[version='>=3.6,<3.7.0a0']
# h5py -> cached-property -> python=3.6
# python==3.8.5=h7579374_1
# packaging -> pyparsing[version='>=2.0.2'] -> python
# pdbfixer -> python
# jupyter_core -> python_abi=3.6[build=*_cp36m] -> python=3.6
# ipython_genutils -> python
# backports.functools_lru_cache -> python
# typing_extensions -> python[version='>=3.5']
# mdtraj -> setuptools -> python[version='>=3.8,<3.9.0a0']
# matplotlib-base -> python[version='>=3.6,<3.7.0a0']
# jupyter_core -> python[version='>=3.6,<3.7.0a0']
# jupyter_client -> jupyter_core[version='>=4.6.0'] -> python[version='>=3.6,<3.7.0a0']
# jedi -> parso[version='>=0.8.0,<0.9.0'] -> python[version='3.6.*|>=3.6']
# numexpr -> python[version='>=3.6,<3.7.0a0']
# rdkit -> python[version='>=3.6,<3.7.0a0']
# importlib_metadata -> importlib-metadata[version='>=3.4.0,<3.4.1.0a0'] -> python[version='>=3.6,<3.7.0a0']
# pillow -> olefile -> python=3.6
# openmm -> cython -> python[version='>=3.6,<3.7.0a0']
# tensorboard -> markdown[version='>=2.6.8'] -> python[version='>=3.8,<3.9.0a0']
# deepchem-gpu -> joblib -> python[version='>=3.6']
# decorator -> python
# pandocfilters -> python
# jsonschema -> python[version='>=3.6']
# tensorflow-estimator -> astor[version='>=0.6.0'] -> python[version='>=3.8,<3.9.0a0']
# qtconsole -> ipykernel[version='>=4.1'] -> python[version='>=3.5|>=3.6,<3.7.0a0']
# python-dateutil -> python
# pip==20.2.4=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0']
# tensorflow -> python_abi=3.6[build=*_cp36m] -> python[version='3.6.*|>=3.6,<3.7.0a0']
# py-xgboost -> python_abi=3.6[build=*_cp36m] -> python=3.6
# cycler -> python
# ruamel_yaml==0.15.87=py38h7b6447c_1 -> python[version='>=3.8,<3.9.0a0']
# jupyterlab_widgets -> python[version='>=3.6']
# terminado -> ptyprocess -> python=3.6
# ipython -> backcall -> python[version='3.6.*|>=3.5|>=3|>=3.6|>=3.8,<3.9.0a0']
# requests==2.24.0=py_0 -> certifi[version='>=2017.4.17'] -> python[version='<4.0|>=3.6,<3.7.0a0|>=3.8,<3.9.0a0']
# werkzeug -> python
# certifi==2020.6.20=pyhd3eb1b0_3 -> python
# markupsafe -> python_abi=3.6[build=*_cp36m] -> python=3.6
# cycler -> six -> python[version='>=3.8,<3.9.0a0']
# pip==20.2.4=py38h06a4308_0 -> setuptools -> python[version='>=3.6,<3.7.0a0']
# scikit-learn -> python[version='>=3.6,<3.7.0a0']
# wrapt -> python_abi=3.6[build=*_cp36m] -> python=3.6
# testpath -> python
# tornado -> python_abi=3.6[build=*_cp36m] -> python=3.6
# simdna -> python
# cached-property -> python
# matplotlib -> python[version='>=3.6,<3.7.0a0']
# nbclient -> python[version='>=3.6']
# attrs -> python
# defusedxml -> python
# zipp -> python[version='>=3.6']
# astor -> python
# py-boost -> python[version='>=3.6,<3.7.0a0']
# nbformat -> python[version='>=3.5']
# pexpect -> python
# cffi==1.14.3=py38h261ae71_2 -> python[version='>=3.8,<3.9.0a0']
# markupsafe -> python[version='>=3.6,<3.7.0a0']
# pycosat==0.6.3=py38h7b6447c_1 -> python[version='>=3.8,<3.9.0a0']
# deepchem-gpu -> python[version='>=3.6,<3.7.0a0']
# brotlipy==0.7.0=py38h27cfd23_1003 -> cffi[version='>=1.0.0'] -> python[version='>=3.6,<3.7.0a0']
# six==1.15.0=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0']
# requests==2.24.0=py_0 -> python
# markdown -> importlib-metadata -> python[version='>=3.6,<3.7.0a0']
# tqdm==4.51.0=pyhd3eb1b0_0 -> python
# sip -> python[version='>=3.6,<3.7.0a0']
# mock -> python_abi=3.6[build=*_cp36m] -> python[version='3.6.*|>=3.8,<3.9.0a0']
# pyrsistent -> python_abi=3.6[build=*_cp36m] -> python=3.6
# pyopenssl==19.1.0=pyhd3eb1b0_1 -> python
# pyzmq -> python[version='>=3.6,<3.7.0a0']
# matplotlib-base -> certifi[version='>=2020.06.20'] -> python[version='3.6.*|>=3.8,<3.9.0a0']
# argon2-cffi -> cffi[version='>=1.0.0'] -> python[version='3.6.*|>=3.8,<3.9.0a0']
# widgetsnbextension -> python_abi=3.6[build=*_cp36m] -> python=3.6
# openmm -> python=3.6
# prometheus_client -> python
# cffi==1.14.3=py38h261ae71_2 -> pycparser -> python
# google-pasta -> python
# backports -> python
# pytables -> python[version='>=3.6,<3.7.0a0']
# pygments -> setuptools -> python[version='>=3.6,<3.7.0a0|>=3.8,<3.9.0a0']
# urllib3==1.25.11=py_0 -> brotlipy[version='>=0.6.0'] -> python[version='>=3.6,<3.7.0a0|>=3.8,<3.9.0a0']
# scipy -> python[version='>=3.6,<3.7.0a0']
# notebook -> ipython_genutils -> python[version='3.6.*|>=3.5']
# parso -> python[version='>=3.6']
# scipy -> python_abi=3.6[build=*_cp36m] -> python=3.6
# nbconvert -> python[version='>=3.6,<3.7.0a0']
# jedi -> python[version='>=3.6,<3.7.0a0']
# gast -> python
# async_generator -> python[version='>2.7']
# pygments -> python[version='>=3.5']
# cython -> python[version='>=3.6,<3.7.0a0']
# joblib -> python[version='>=3.6']
# backcall -> python
# backports.functools_lru_cache -> setuptools -> python[version='>=3.6,<3.7.0a0|>=3.8,<3.9.0a0']
# tensorboard -> python[version='>=3.6,<3.7.0a0']
# absl-py -> python[version='>=3.6,<3.7.0a0']
# numpy -> python[version='>=3.6,<3.7.0a0']
# conda==4.9.2=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0']
# qtpy -> python
# wcwidth -> python
# threadpoolctl -> python[version='>=3.5']
# scikit-learn -> joblib[version='>=0.11'] -> python[version='3.6.*|>=3.6|>=3.5']
# mistune -> python_abi=3.6[build=*_cp36m] -> python=3.6
# py-xgboost -> python[version='>=3.6,<3.7.0a0']
# mistune -> python[version='>=3.6,<3.7.0a0']
# entrypoints -> python[version='>=3.6']
# nbconvert -> bleach -> python[version='3.6.*|>=3.5|>=3.6']
# widgetsnbextension -> python[version='>=3.6,<3.7.0a0']
# grpcio -> python[version='>=3.6,<3.7.0a0']
# qtconsole -> python[version='>=3.6']
# conda-package-handling==1.7.2=py38h03888b9_0 -> six -> python
# pandas -> python[version='>=3.6,<3.7.0a0']
# bleach -> python
# keras-applications -> h5py -> python[version='>=3.6,<3.7.0a0']
# numexpr -> python_abi=3.6[build=*_cp36m] -> python[version='3.6.*|>=3.8,<3.9.0a0']
# python_abi -> python=3.6
# pysocks==1.7.1=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0']
# nest-asyncio -> python[version='>=3.5']
# pyzmq -> python_abi=3.6[build=*_cp36m] -> python=3.6
# networkx -> python[version='>=3.6']
# pdbfixer -> numpy[version='>=1.14'] -> python[version='3.6.*|>=3.6,<3.7.0a0']
# prompt_toolkit -> prompt-toolkit[version='>=3.0.10,<3.0.11.0a0'] -> python[version='>=3.6']
# wheel==0.35.1=pyhd3eb1b0_0 -> python
# ipykernel -> jupyter_client -> python[version='3.6.*|>=3.5']
# kiwisolver -> python_abi=3.6[build=*_cp36m] -> python=3.6
# pyqt -> python[version='>=3.6,<3.7.0a0']
# setuptools==50.3.1=py38h06a4308_1 -> python[version='>=3.8,<3.9.0a0']
# pyopenssl==19.1.0=pyhd3eb1b0_1 -> cryptography[version='>=2.8'] -> python[version='>=3.6,<3.7.0a0|>=3.8,<3.9.0a0']
# brotlipy==0.7.0=py38h27cfd23_1003 -> python[version='>=3.8,<3.9.0a0']
# importlib-metadata -> python[version='>=3.6,<3.7.0a0']
# xgboost -> python[version='>=3.6,<3.7.0a0']
# cryptography==3.2.1=py38h3c74f83_1 -> python[version='>=3.8,<3.9.0a0']
# conda-package-handling==1.7.2=py38h03888b9_0 -> python[version='>=3.8,<3.9.0a0']
# pandas -> python-dateutil[version='>=2.7.3'] -> python[version='3.6.*|>=3']
# tensorflow-estimator -> python[version='>=3.6,<3.7.0a0']
# pillow -> python[version='>=3.6,<3.7.0a0']
# notebook -> python[version='>=3.6,<3.7.0a0']
# keras-preprocessing -> numpy[version='>=1.9.1'] -> python[version='>=3.6,<3.7.0a0|>=3.8,<3.9.0a0']
# pycparser==2.20=py_2 -> python
# setuptools==50.3.1=py38h06a4308_1 -> certifi[version='>=2016.9.26'] -> python[version='>=3.6,<3.7.0a0']
# pytables -> python_abi=3.6[build=*_cp36m] -> python[version='3.6.*|>=3.8,<3.9.0a0']
#
# Package ncurses conflicts for:
# xgboost -> python[version='>=3.6,<3.7.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# google-pasta -> python -> ncurses[version='>=6.2,<7.0a0']
# pexpect -> python -> ncurses[version='>=6.2,<7.0a0']
# numexpr -> python[version='>=3.6,<3.7.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# backports.functools_lru_cache -> python -> ncurses[version='>=6.2,<7.0a0']
# jinja2 -> python -> ncurses[version='>=6.2,<7.0a0']
# widgetsnbextension -> python[version='>=3.6,<3.7.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# chardet==3.0.4=py38h06a4308_1003 -> python[version='>=3.8,<3.9.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# keras-preprocessing -> python -> ncurses[version='>=6.2,<7.0a0']
# jupyterlab_pygments -> python -> ncurses[version='>=6.2,<7.0a0']
# tqdm==4.51.0=pyhd3eb1b0_0 -> python -> ncurses[version='>=6.2,<7.0a0']
# matplotlib -> python[version='>=3.6,<3.7.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# threadpoolctl -> python[version='>=3.5'] -> ncurses[version='>=6.2,<7.0a0']
# numpy -> python[version='>=3.6,<3.7.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# h5py -> python[version='>=3.6,<3.7.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# backcall -> python -> ncurses[version='>=6.2,<7.0a0']
# jupyter_console -> python[version='>=3.6'] -> ncurses[version='>=6.2,<7.0a0']
# joblib -> python[version='>=3.6'] -> ncurses[version='>=6.2,<7.0a0']
# qtconsole -> python[version='>=3.6'] -> ncurses[version='>=6.2,<7.0a0']
# qt -> sqlite[version='>=3.25.3,<4.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# python==3.8.5=h7579374_1 -> readline[version='>=8.0,<9.0a0'] -> ncurses[version='>=6.1,<7.0a0']
# wcwidth -> python -> ncurses[version='>=6.2,<7.0a0']
# traitlets -> python[version='>=3.6,<3.7.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# packaging -> python[version='>=2.7'] -> ncurses[version='>=6.2,<7.0a0']
# setuptools==50.3.1=py38h06a4308_1 -> python[version='>=3.8,<3.9.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# nbformat -> python[version='>=3.5'] -> ncurses[version='>=6.2,<7.0a0']
# nbclient -> python[version='>=3.6'] -> ncurses[version='>=6.2,<7.0a0']
# cached-property -> python -> ncurses[version='>=6.2,<7.0a0']
# python-dateutil -> python -> ncurses[version='>=6.2,<7.0a0']
# certifi==2020.6.20=pyhd3eb1b0_3 -> python -> ncurses[version='>=6.2,<7.0a0']
# sqlite==3.33.0=h62c20be_0 -> ncurses[version='>=6.2,<7.0a0']
# conda-package-handling==1.7.2=py38h03888b9_0 -> python[version='>=3.8,<3.9.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# deepchem-gpu -> python[version='>=3.6,<3.7.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# terminado -> python[version='>=3.6,<3.7.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# parso -> python[version='>=3.6'] -> ncurses[version='>=6.2,<7.0a0']
# py-xgboost -> python[version='>=3.6,<3.7.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# ncurses==6.2=he6710b0_1
# tensorflow-base -> python[version='>=3.6,<3.7.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# jsonschema -> python[version='>=3.6'] -> ncurses[version='>=6.2,<7.0a0']
# markdown -> python -> ncurses[version='>=6.2,<7.0a0']
# importlib-metadata -> python[version='>=3.6,<3.7.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# pycosat==0.6.3=py38h7b6447c_1 -> python[version='>=3.8,<3.9.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# jupyter_client -> python[version='>=3.5'] -> ncurses[version='>=6.2,<7.0a0']
# pysocks==1.7.1=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# six==1.15.0=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# tornado -> python[version='>=3.6,<3.7.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# requests==2.24.0=py_0 -> python -> ncurses[version='>=6.2,<7.0a0']
# py-boost -> python[version='>=3.6,<3.7.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# pyqt -> python[version='>=3.6,<3.7.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# astor -> python -> ncurses[version='>=6.2,<7.0a0']
# cffi==1.14.3=py38h261ae71_2 -> python[version='>=3.8,<3.9.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# ipywidgets -> python -> ncurses[version='>=6.2,<7.0a0']
# nbconvert -> python[version='>=3.6,<3.7.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# urllib3==1.25.11=py_0 -> python[version='<4.0'] -> ncurses[version='>=6.2,<7.0a0']
# cryptography==3.2.1=py38h3c74f83_1 -> python[version='>=3.8,<3.9.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# zipp -> python[version='>=3.6'] -> ncurses[version='>=6.2,<7.0a0']
# pickleshare -> python[version='>=3'] -> ncurses[version='>=6.2,<7.0a0']
# tensorboard -> python[version='>=3.6,<3.7.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# pyrsistent -> python[version='>=3.6,<3.7.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# attrs -> python -> ncurses[version='>=6.2,<7.0a0']
# cycler -> python -> ncurses[version='>=6.2,<7.0a0']
# jedi -> python[version='>=3.6,<3.7.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# jupyterlab_widgets -> python[version='>=3.6'] -> ncurses[version='>=6.2,<7.0a0']
# jupyter -> python -> ncurses[version='>=6.2,<7.0a0']
# pdbfixer -> python -> ncurses[version='>=6.2,<7.0a0']
# jupyter_core -> python[version='>=3.6,<3.7.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# pyopenssl==19.1.0=pyhd3eb1b0_1 -> python -> ncurses[version='>=6.2,<7.0a0']
# idna==2.10=py_0 -> python -> ncurses[version='>=6.2,<7.0a0']
# pip==20.2.4=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# pycparser==2.20=py_2 -> python -> ncurses[version='>=6.2,<7.0a0']
# pillow -> python[version='>=3.6,<3.7.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# ptyprocess -> python -> ncurses[version='>=6.2,<7.0a0']
# pyparsing -> python -> ncurses[version='>=6.2,<7.0a0']
# pytz -> python[version='>=3'] -> ncurses[version='>=6.2,<7.0a0']
# pyzmq -> python[version='>=3.6,<3.7.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# prompt-toolkit -> python[version='>=3.6'] -> ncurses[version='>=6.2,<7.0a0']
# absl-py -> python[version='>=3.6,<3.7.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# ipython_genutils -> python -> ncurses[version='>=6.2,<7.0a0']
# krb5 -> libedit[version='>=3.1.20191231,<3.2.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# entrypoints -> python[version='>=3.6'] -> ncurses[version='>=6.2,<7.0a0']
# pandocfilters -> python -> ncurses[version='>=6.2,<7.0a0']
# mdtraj -> python[version='>=3.6,<3.7.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# pytables -> python[version='>=3.6,<3.7.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# brotlipy==0.7.0=py38h27cfd23_1003 -> python[version='>=3.8,<3.9.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# scipy -> python[version='>=3.6,<3.7.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# gast -> python -> ncurses[version='>=6.2,<7.0a0']
# wheel==0.35.1=pyhd3eb1b0_0 -> python -> ncurses[version='>=6.2,<7.0a0']
# readline==8.0=h7b6447c_0 -> ncurses[version='>=6.1,<7.0a0']
# typing_extensions -> python[version='>=3.5'] -> ncurses[version='>=6.2,<7.0a0']
# webencodings -> python -> ncurses[version='>=6.2,<7.0a0']
# tensorflow-estimator -> python[version='>=3.6,<3.7.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# matplotlib-base -> python[version='>=3.6,<3.7.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# backports -> python -> ncurses[version='>=6.2,<7.0a0']
# networkx -> python[version='>=3.6'] -> ncurses[version='>=6.2,<7.0a0']
# decorator -> python -> ncurses[version='>=6.2,<7.0a0']
# python_abi -> python=3.6 -> ncurses[version='>=6.2,<7.0a0']
# mistune -> python[version='>=3.6,<3.7.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# argon2-cffi -> python[version='>=3.6,<3.7.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# ruamel_yaml==0.15.87=py38h7b6447c_1 -> python[version='>=3.8,<3.9.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# werkzeug -> python -> ncurses[version='>=6.2,<7.0a0']
# scikit-learn -> python[version='>=3.6,<3.7.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# termcolor -> python -> ncurses[version='>=6.2,<7.0a0']
# ipykernel -> python[version='>=3.6,<3.7.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# async_generator -> python[version='>2.7'] -> ncurses[version='>=6.2,<7.0a0']
# pygments -> python[version='>=3.5'] -> ncurses[version='>=6.2,<7.0a0']
# rdkit -> python[version='>=3.6,<3.7.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# testpath -> python -> ncurses[version='>=6.2,<7.0a0']
# libedit==3.1.20191231=h14c3975_1 -> ncurses[version='>=6.2,<7.0a0']
# openmm -> python=3.6 -> ncurses[version='>=6.2,<7.0a0']
# ipython -> python[version='>=3.6,<3.7.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# cython -> python[version='>=3.6,<3.7.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# olefile -> python -> ncurses[version='>=6.2,<7.0a0']
# mock -> python[version='>=3.6,<3.7.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# nest-asyncio -> python[version='>=3.5'] -> ncurses[version='>=6.2,<7.0a0']
# send2trash -> python -> ncurses[version='>=6.2,<7.0a0']
# pandas -> python[version='>=3.6,<3.7.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# kiwisolver -> python[version='>=3.6,<3.7.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# qtpy -> python -> ncurses[version='>=6.2,<7.0a0']
# bleach -> python -> ncurses[version='>=6.2,<7.0a0']
# conda==4.9.2=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# simdna -> python -> ncurses[version='>=6.2,<7.0a0']
# prometheus_client -> python -> ncurses[version='>=6.2,<7.0a0']
# sip -> python[version='>=3.6,<3.7.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# wrapt -> python[version='>=3.6,<3.7.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# markupsafe -> python[version='>=3.6,<3.7.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# python==3.8.5=h7579374_1 -> ncurses[version='>=6.2,<7.0a0']
# grpcio -> python[version='>=3.6,<3.7.0a0'] -> ncurses[version='>=6.2,<7.0a0']
# defusedxml -> python -> ncurses[version='>=6.2,<7.0a0']
# keras-applications -> python -> ncurses[version='>=6.2,<7.0a0']
# notebook -> python[version='>=3.6,<3.7.0a0'] -> ncurses[version='>=6.2,<7.0a0']
#
# Package ld_impl_linux-64 conflicts for:
# nest-asyncio -> python[version='>=3.5'] -> ld_impl_linux-64
# grpcio -> python[version='>=3.6,<3.7.0a0'] -> ld_impl_linux-64
# wrapt -> python[version='>=3.6,<3.7.0a0'] -> ld_impl_linux-64
# tensorboard -> python[version='>=3.6,<3.7.0a0'] -> ld_impl_linux-64
# matplotlib-base -> python[version='>=3.6,<3.7.0a0'] -> ld_impl_linux-64
# pyrsistent -> python[version='>=3.6,<3.7.0a0'] -> ld_impl_linux-64
# attrs -> python -> ld_impl_linux-64
# simdna -> python -> ld_impl_linux-64
# jedi -> python[version='>=3.6,<3.7.0a0'] -> ld_impl_linux-64
# google-pasta -> python -> ld_impl_linux-64
# markupsafe -> python[version='>=3.6,<3.7.0a0'] -> ld_impl_linux-64
# backports.functools_lru_cache -> python -> ld_impl_linux-64
# six==1.15.0=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> ld_impl_linux-64
# pdbfixer -> python -> ld_impl_linux-64
# astor -> python -> ld_impl_linux-64
# ld_impl_linux-64==2.33.1=h53a641e_7
# idna==2.10=py_0 -> python -> ld_impl_linux-64
# pip==20.2.4=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> ld_impl_linux-64
# pytz -> python[version='>=3'] -> ld_impl_linux-64
# ptyprocess -> python -> ld_impl_linux-64
# prompt-toolkit -> python[version='>=3.6'] -> ld_impl_linux-64
# tqdm==4.51.0=pyhd3eb1b0_0 -> python -> ld_impl_linux-64
# absl-py -> python[version='>=3.6,<3.7.0a0'] -> ld_impl_linux-64
# pandocfilters -> python -> ld_impl_linux-64
# mdtraj -> python[version='>=3.6,<3.7.0a0'] -> ld_impl_linux-64
# h5py -> python[version='>=3.6,<3.7.0a0'] -> ld_impl_linux-64
# pytables -> python[version='>=3.6,<3.7.0a0'] -> ld_impl_linux-64
# pyopenssl==19.1.0=pyhd3eb1b0_1 -> python -> ld_impl_linux-64
# brotlipy==0.7.0=py38h27cfd23_1003 -> python[version='>=3.8,<3.9.0a0'] -> ld_impl_linux-64
# scipy -> python[version='>=3.6,<3.7.0a0'] -> ld_impl_linux-64
# gast -> python -> ld_impl_linux-64
# bleach -> python -> ld_impl_linux-64
# entrypoints -> python[version='>=3.6'] -> ld_impl_linux-64
# backports -> python -> ld_impl_linux-64
# networkx -> python[version='>=3.6'] -> ld_impl_linux-64
# prometheus_client -> python -> ld_impl_linux-64
# argon2-cffi -> python[version='>=3.6,<3.7.0a0'] -> ld_impl_linux-64
# sip -> python[version='>=3.6,<3.7.0a0'] -> ld_impl_linux-64
# scikit-learn -> python[version='>=3.6,<3.7.0a0'] -> ld_impl_linux-64
# ipykernel -> python[version='>=3.6,<3.7.0a0'] -> ld_impl_linux-64
# pandas -> python[version='>=3.6,<3.7.0a0'] -> ld_impl_linux-64
# pyzmq -> python[version='>=3.6,<3.7.0a0'] -> ld_impl_linux-64
# defusedxml -> python -> ld_impl_linux-64
# async_generator -> python[version='>2.7'] -> ld_impl_linux-64
# ipython_genutils -> python -> ld_impl_linux-64
# numexpr -> python[version='>=3.6,<3.7.0a0'] -> ld_impl_linux-64
# pygments -> python[version='>=3.5'] -> ld_impl_linux-64
# rdkit -> python[version='>=3.6,<3.7.0a0'] -> ld_impl_linux-64
# testpath -> python -> ld_impl_linux-64
# tornado -> python[version='>=3.6,<3.7.0a0'] -> ld_impl_linux-64
# openmm -> python=3.6 -> ld_impl_linux-64
# webencodings -> python -> ld_impl_linux-64
# backcall -> python -> ld_impl_linux-64
# cython -> python[version='>=3.6,<3.7.0a0'] -> ld_impl_linux-64
# kiwisolver -> python[version='>=3.6,<3.7.0a0'] -> ld_impl_linux-64
# olefile -> python -> ld_impl_linux-64
# mistune -> python[version='>=3.6,<3.7.0a0'] -> ld_impl_linux-64
# send2trash -> python -> ld_impl_linux-64
# qtpy -> python -> ld_impl_linux-64
# jinja2 -> python -> ld_impl_linux-64
# conda==4.9.2=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> ld_impl_linux-64
# jsonschema -> python[version='>=3.6'] -> ld_impl_linux-64
# keras-preprocessing -> python -> ld_impl_linux-64
# chardet==3.0.4=py38h06a4308_1003 -> python[version='>=3.8,<3.9.0a0'] -> ld_impl_linux-64
# python==3.8.5=h7579374_1 -> ld_impl_linux-64
# certifi==2020.6.20=pyhd3eb1b0_3 -> python -> ld_impl_linux-64
# deepchem-gpu -> python[version='>=3.6,<3.7.0a0'] -> ld_impl_linux-64
# xgboost -> python[version='>=3.6,<3.7.0a0'] -> ld_impl_linux-64
# pexpect -> python -> ld_impl_linux-64
# widgetsnbextension -> python[version='>=3.6,<3.7.0a0'] -> ld_impl_linux-64
# pillow -> python[version='>=3.6,<3.7.0a0'] -> ld_impl_linux-64
# ipython -> python[version='>=3.6,<3.7.0a0'] -> ld_impl_linux-64
# jupyterlab_pygments -> python -> ld_impl_linux-64
# werkzeug -> python -> ld_impl_linux-64
# threadpoolctl -> python[version='>=3.5'] -> ld_impl_linux-64
# numpy -> python[version='>=3.6,<3.7.0a0'] -> ld_impl_linux-64
# joblib -> python[version='>=3.6'] -> ld_impl_linux-64
# mock -> python[version='>=3.6,<3.7.0a0'] -> ld_impl_linux-64
# qtconsole -> python[version='>=3.6'] -> ld_impl_linux-64
# ipywidgets -> python -> ld_impl_linux-64
# pickleshare -> python[version='>=3'] -> ld_impl_linux-64
# typing_extensions -> python[version='>=3.5'] -> ld_impl_linux-64
# decorator -> python -> ld_impl_linux-64
# wcwidth -> python -> ld_impl_linux-64
# keras-applications -> python -> ld_impl_linux-64
# traitlets -> python[version='>=3.6,<3.7.0a0'] -> ld_impl_linux-64
# packaging -> python[version='>=2.7'] -> ld_impl_linux-64
# setuptools==50.3.1=py38h06a4308_1 -> python[version='>=3.8,<3.9.0a0'] -> ld_impl_linux-64
# jupyter_console -> python[version='>=3.6'] -> ld_impl_linux-64
# nbformat -> python[version='>=3.5'] -> ld_impl_linux-64
# python_abi -> python=3.6 -> ld_impl_linux-64
# python-dateutil -> python -> ld_impl_linux-64
# ruamel_yaml==0.15.87=py38h7b6447c_1 -> python[version='>=3.8,<3.9.0a0'] -> ld_impl_linux-64
# conda-package-handling==1.7.2=py38h03888b9_0 -> python[version='>=3.8,<3.9.0a0'] -> ld_impl_linux-64
# pycparser==2.20=py_2 -> python -> ld_impl_linux-64
# termcolor -> python -> ld_impl_linux-64
# terminado -> python[version='>=3.6,<3.7.0a0'] -> ld_impl_linux-64
# wheel==0.35.1=pyhd3eb1b0_0 -> python -> ld_impl_linux-64
# py-xgboost -> python[version='>=3.6,<3.7.0a0'] -> ld_impl_linux-64
# matplotlib -> python[version='>=3.6,<3.7.0a0'] -> ld_impl_linux-64
# parso -> python[version='>=3.6'] -> ld_impl_linux-64
# tensorflow-base -> python[version='>=3.6,<3.7.0a0'] -> ld_impl_linux-64
# markdown -> python -> ld_impl_linux-64
# jupyter -> python -> ld_impl_linux-64
# importlib-metadata -> python[version='>=3.6,<3.7.0a0'] -> ld_impl_linux-64
# pycosat==0.6.3=py38h7b6447c_1 -> python[version='>=3.8,<3.9.0a0'] -> ld_impl_linux-64
# jupyter_core -> python[version='>=3.6,<3.7.0a0'] -> ld_impl_linux-64
# jupyter_client -> python[version='>=3.5'] -> ld_impl_linux-64
# pysocks==1.7.1=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> ld_impl_linux-64
# requests==2.24.0=py_0 -> python -> ld_impl_linux-64
# py-boost -> python[version='>=3.6,<3.7.0a0'] -> ld_impl_linux-64
# notebook -> python[version='>=3.6,<3.7.0a0'] -> ld_impl_linux-64
# jupyterlab_widgets -> python[version='>=3.6'] -> ld_impl_linux-64
# pyparsing -> python -> ld_impl_linux-64
# pyqt -> python[version='>=3.6,<3.7.0a0'] -> ld_impl_linux-64
# cffi==1.14.3=py38h261ae71_2 -> python[version='>=3.8,<3.9.0a0'] -> ld_impl_linux-64
# nbclient -> python[version='>=3.6'] -> ld_impl_linux-64
# tensorflow-estimator -> python[version='>=3.6,<3.7.0a0'] -> ld_impl_linux-64
# cached-property -> python -> ld_impl_linux-64
# nbconvert -> python[version='>=3.6,<3.7.0a0'] -> ld_impl_linux-64
# urllib3==1.25.11=py_0 -> python[version='<4.0'] -> ld_impl_linux-64
# cryptography==3.2.1=py38h3c74f83_1 -> python[version='>=3.8,<3.9.0a0'] -> ld_impl_linux-64
# cycler -> python -> ld_impl_linux-64
# zipp -> python[version='>=3.6'] -> ld_impl_linux-64
#
# Package numexpr conflicts for:
# numexpr
# mdtraj -> pytables -> numexpr
# pytables -> numexpr
#
# Package libgcc-ng conflicts for:
# libboost -> libgcc-ng[version='>=7.3.0']
# pandocfilters -> python -> libgcc-ng[version='>=7.3.0']
# absl-py -> python[version='>=3.6,<3.7.0a0'] -> libgcc-ng[version='>=7.3.0']
# fontconfig -> freetype[version='>=2.9.1,<3.0a0'] -> libgcc-ng[version='>=7.5.0']
# libprotobuf -> zlib[version='>=1.2.11,<1.3.0a0'] -> libgcc-ng[version='>=7.3.0']
# pyrsistent -> libgcc-ng[version='>=7.5.0']
# brotlipy==0.7.0=py38h27cfd23_1003 -> libgcc-ng[version='>=7.3.0']
# send2trash -> python -> libgcc-ng[version='>=7.3.0']
# c-ares -> libgcc-ng[version='>=7.5.0']
# sip -> libgcc-ng[version='>=7.3.0']
# py-boost -> libgcc-ng[version='>=7.3.0']
# urllib3==1.25.11=py_0 -> brotlipy[version='>=0.6.0'] -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# cairo -> libgcc-ng[version='>=7.3.0']
# conda-package-handling==1.7.2=py38h03888b9_0 -> libgcc-ng[version='>=7.3.0']
# tensorflow-base -> libgcc-ng[version='>=5.4.0']
# python_abi -> python=3.6 -> libgcc-ng[version='>=7.3.0']
# bleach -> python -> libgcc-ng[version='>=7.3.0']
# libgcc-ng==9.1.0=hdf63c60_0
# cycler -> python -> libgcc-ng[version='>=7.3.0']
# tensorflow -> libgcc-ng[version='>=5.4.0']
# typing_extensions -> python[version='>=3.5'] -> libgcc-ng[version='>=7.3.0']
# libblas -> libopenblas[version='>=0.3.12,<0.3.13.0a0'] -> libgcc-ng[version='>=7.5.0']
# scikit-learn -> python[version='>=3.6,<3.7.0a0'] -> libgcc-ng[version='>=7.3.0']
# wcwidth -> python -> libgcc-ng[version='>=7.3.0']
# py-xgboost -> libxgboost==1.2.0=he1b5a44_0 -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# importlib-metadata -> python[version='>=3.6,<3.7.0a0'] -> libgcc-ng[version='>=7.3.0']
# freetype -> libgcc-ng[version='>=7.5.0']
# xorg-libxext -> xorg-libx11=1.6 -> libgcc-ng[version='>=7.5.0']
# numexpr -> python[version='>=3.6,<3.7.0a0'] -> libgcc-ng[version='>=7.3.0']
# pygments -> python[version='>=3.5'] -> libgcc-ng[version='>=7.3.0']
# terminado -> python[version='>=3.6,<3.7.0a0'] -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# testpath -> python -> libgcc-ng[version='>=7.3.0']
# libxml2 -> libgcc-ng[version='>=7.3.0']
# kiwisolver -> libgcc-ng[version='>=7.5.0']
# libnghttp2 -> openssl[version='>=1.1.1g,<1.1.2a'] -> libgcc-ng[version='>=7.3.0']
# pyzmq -> libgcc-ng[version='>=7.5.0']
# pillow -> python[version='>=3.6,<3.7.0a0'] -> libgcc-ng[version='>=7.3.0']
# notebook -> argon2-cffi -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# libffi==3.3=he6710b0_2 -> libgcc-ng[version='>=7.3.0']
# dbus -> libgcc-ng[version='>=7.3.0']
# blosc -> libgcc-ng[version='>=7.5.0']
# xgboost -> libgcc-ng[version='>=7.5.0']
# libuuid -> libgcc-ng[version='>=7.3.0']
# astor -> python -> libgcc-ng[version='>=7.3.0']
# prompt-toolkit -> python[version='>=3.6'] -> libgcc-ng[version='>=7.3.0']
# cryptography==3.2.1=py38h3c74f83_1 -> libgcc-ng[version='>=7.3.0']
# zeromq -> libgcc-ng[version='>=7.5.0']
# jupyter_client -> python[version='>=3.5'] -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# zstd -> xz[version='>=5.2.5,<5.3.0a0'] -> libgcc-ng[version='>=7.3.0']
# backcall -> python -> libgcc-ng[version='>=7.3.0']
# tensorboard -> numpy[version='>=1.12.0'] -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# h5py -> python[version='>=3.6,<3.7.0a0'] -> libgcc-ng[version='>=7.3.0']
# xz==5.2.5=h7b6447c_0 -> libgcc-ng[version='>=7.3.0']
# cython -> python[version='>=3.6,<3.7.0a0'] -> libgcc-ng[version='>=7.3.0']
# mdtraj -> numpy[version='>=1.8'] -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# xorg-libx11 -> libgcc-ng[version='>=7.5.0']
# keras-applications -> h5py -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# ptyprocess -> python -> libgcc-ng[version='>=7.3.0']
# tqdm==4.51.0=pyhd3eb1b0_0 -> python -> libgcc-ng[version='>=7.3.0']
# qt -> libgcc-ng[version='>=7.3.0']
# xorg-libxau -> libgcc-ng[version='>=7.3.0']
# krb5 -> libgcc-ng[version='>=7.5.0']
# pcre -> libgcc-ng[version='>=7.3.0']
# tk==8.6.10=hbc83047_0 -> libgcc-ng[version='>=7.3.0']
# tornado -> python[version='>=3.6,<3.7.0a0'] -> libgcc-ng[version='>=7.3.0']
# freetype -> zlib[version='>=1.2.11,<1.3.0a0'] -> libgcc-ng[version='>=7.3.0']
# libpng -> libgcc-ng[version='>=7.5.0']
# pytables -> python[version='>=3.6,<3.7.0a0'] -> libgcc-ng[version='>=7.3.0']
# jpeg -> libgcc-ng[version='>=7.5.0']
# nest-asyncio -> python[version='>=3.5'] -> libgcc-ng[version='>=7.3.0']
# tensorflow -> libcurl[version='>=7.71.1,<8.0a0'] -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# libprotobuf -> libgcc-ng[version='>=7.5.0']
# gstreamer -> libgcc-ng[version='>=7.3.0']
# traitlets -> python[version='>=3.6,<3.7.0a0'] -> libgcc-ng[version='>=7.3.0']
# scipy -> python[version='>=3.6,<3.7.0a0'] -> libgcc-ng[version='>=7.3.0']
# packaging -> python[version='>=2.7'] -> libgcc-ng[version='>=7.3.0']
# nbformat -> python[version='>=3.5'] -> libgcc-ng[version='>=7.3.0']
# python==3.8.5=h7579374_1 -> openssl[version='>=1.1.1g,<1.1.2a'] -> libgcc-ng[version='>=7.5.0']
# prometheus_client -> python -> libgcc-ng[version='>=7.3.0']
# xorg-libsm -> libgcc-ng[version='>=7.3.0']
# python-dateutil -> python -> libgcc-ng[version='>=7.3.0']
# python==3.8.5=h7579374_1 -> libgcc-ng[version='>=7.3.0']
# certifi==2020.6.20=pyhd3eb1b0_3 -> python -> libgcc-ng[version='>=7.3.0']
# qtconsole -> pyqt -> libgcc-ng[version='>=7.3.0']
# mistune -> libgcc-ng[version='>=7.5.0']
# argon2-cffi -> libgcc-ng[version='>=7.5.0']
# libwebp-base -> libgcc-ng[version='>=7.5.0']
# xorg-xextproto -> libgcc-ng[version='>=7.3.0']
# xorg-libxext -> libgcc-ng[version='>=7.3.0']
# lz4-c -> libgcc-ng[version='>=7.5.0']
# readline==8.0=h7b6447c_0 -> libgcc-ng[version='>=7.3.0']
# cached-property -> python -> libgcc-ng[version='>=7.3.0']
# markupsafe -> libgcc-ng[version='>=7.5.0']
# lcms2 -> libgcc-ng[version='>=7.5.0']
# libxml2 -> libiconv[version='>=1.15,<1.17.0a0'] -> libgcc-ng[version='>=7.5.0']
# gast -> python -> libgcc-ng[version='>=7.3.0']
# keras-preprocessing -> numpy[version='>=1.9.1'] -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# xorg-libx11 -> libxcb=1 -> libgcc-ng[version='>=7.3.0']
# libcurl -> openssl[version='>=1.1.1h,<1.1.2a'] -> libgcc-ng[version='>=7.3.0']
# idna==2.10=py_0 -> python -> libgcc-ng[version='>=7.3.0']
# bzip2 -> libgcc-ng[version='>=7.5.0']
# ncurses==6.2=he6710b0_1 -> libgcc-ng[version='>=7.3.0']
# argon2-cffi -> cffi[version='>=1.0.0'] -> libgcc-ng[version='>=7.3.0']
# defusedxml -> python -> libgcc-ng[version='>=7.3.0']
# pthread-stubs -> libgcc-ng[version='>=7.5.0']
# pip==20.2.4=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> libgcc-ng[version='>=7.3.0']
# libiconv -> libgcc-ng[version='>=7.5.0']
# libcurl -> libgcc-ng[version='>=7.5.0']
# libboost -> bzip2[version='>=1.0.8,<2.0a0'] -> libgcc-ng[version='>=7.5.0']
# fontconfig -> libgcc-ng[version='>=7.3.0']
# cython -> libgcc-ng[version='>=7.5.0']
# expat -> libgcc-ng[version='>=7.3.0']
# tensorflow-base -> grpcio[version='>=1.8.6'] -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# olefile -> python -> libgcc-ng[version='>=7.3.0']
# glib -> libgcc-ng[version='>=7.3.0']
# wrapt -> libgcc-ng[version='>=7.5.0']
# lzo -> libgcc-ng[version='>=7.5.0']
# matplotlib -> matplotlib-base[version='>=3.3.3,<3.3.4.0a0'] -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# hdf5 -> openssl[version='>=1.1.1h,<1.1.2a'] -> libgcc-ng[version='>=7.3.0']
# h5py -> libgcc-ng[version='>=7.5.0']
# pyzmq -> python[version='>=3.6,<3.7.0a0'] -> libgcc-ng[version='>=7.3.0']
# xorg-xproto -> libgcc-ng[version='>=7.3.0']
# mock -> python[version='>=3.6,<3.7.0a0'] -> libgcc-ng[version='>=7.3.0']
# ipython_genutils -> python -> libgcc-ng[version='>=7.3.0']
# entrypoints -> python[version='>=3.6'] -> libgcc-ng[version='>=7.3.0']
# krb5 -> libedit[version='>=3.1.20191231,<3.2.0a0'] -> libgcc-ng[version='>=7.3.0']
# matplotlib-base -> libgcc-ng[version='>=7.5.0']
# jupyter_console -> python[version='>=3.6'] -> libgcc-ng[version='>=7.3.0']
# joblib -> python[version='>=3.6'] -> libgcc-ng[version='>=7.3.0']
# pyopenssl==19.1.0=pyhd3eb1b0_1 -> cryptography[version='>=2.8'] -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# xorg-kbproto -> libgcc-ng[version='>=7.3.0']
# mistune -> python[version='>=3.6,<3.7.0a0'] -> libgcc-ng[version='>=7.3.0']
# ipywidgets -> python -> libgcc-ng[version='>=7.3.0']
# conda==4.9.2=py38h06a4308_0 -> conda-package-handling[version='>=1.3.0'] -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# libnghttp2 -> libgcc-ng[version='>=7.5.0']
# termcolor -> python -> libgcc-ng[version='>=7.3.0']
# nbconvert -> mistune[version='>=0.8.1'] -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# yaml==0.2.5=h7b6447c_0 -> libgcc-ng[version='>=7.3.0']
# wheel==0.35.1=pyhd3eb1b0_0 -> python -> libgcc-ng[version='>=7.3.0']
# numpy -> libgcc-ng[version='>=7.5.0']
# ipykernel -> python[version='>=3.6,<3.7.0a0'] -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# deepchem-gpu -> pandas -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# libssh2 -> libgcc-ng[version='>=7.5.0']
# parso -> python[version='>=3.6'] -> libgcc-ng[version='>=7.3.0']
# webencodings -> python -> libgcc-ng[version='>=7.3.0']
# zipp -> python[version='>=3.6'] -> libgcc-ng[version='>=7.3.0']
# zstd -> libgcc-ng[version='>=7.5.0']
# libpng -> zlib[version='>=1.2.11,<1.3.0a0'] -> libgcc-ng[version='>=7.3.0']
# ...
# google-pasta
# tensorflow-base -> google-pasta[version='>=0.1.6']
#
# Package fftw3f conflicts for:
# fftw3f
# openmm -> fftw3f
# pdbfixer -> openmm[version='>=7.4.0'] -> fftw3f
#
# Package pysocks conflicts for:
# pysocks==1.7.1=py38h06a4308_0
# urllib3==1.25.11=py_0 -> pysocks[version='>=1.5.6,<2.0,!=1.5.7']
# requests==2.24.0=py_0 -> urllib3[version='>=1.21.1,<1.26,!=1.25.0,!=1.25.1'] -> pysocks[version='>=1.5.6,<2.0,!=1.5.7']
#
# Package pdbfixer conflicts for:
# pdbfixer
# deepchem-gpu -> pdbfixer
#
# Package olefile conflicts for:
# deepchem-gpu -> pillow -> olefile
# matplotlib-base -> pillow[version='>=6.2.0'] -> olefile
# rdkit -> pillow -> olefile
# pillow -> olefile
# olefile
#
# Package parso conflicts for:
# jedi -> parso[version='>=0.8.0,<0.9.0']
# ipython -> jedi[version='>=0.10'] -> parso[version='>=0.8.0,<0.9.0']
# parso
#
# Package absl-py conflicts for:
# tensorflow -> tensorflow-base==1.14.0=py36hc3e5e64_0 -> absl-py[version='>=0.7.0']
# tensorflow-estimator -> absl-py[version='>=0.7.0']
# tensorflow-base -> absl-py[version='>=0.7.0']
# absl-py
#
# Package tensorflow-base conflicts for:
# tensorflow -> tensorflow-base==1.14.0=py36hc3e5e64_0
# tensorflow-base
# tensorflow-gpu -> tensorflow==1.14.0 -> tensorflow-base==1.14.0=py36hc3e5e64_0
#
# Package webencodings conflicts for:
# webencodings
# nbconvert -> bleach -> webencodings
# bleach -> webencodings
#
# Package nest-asyncio conflicts for:
# nbconvert -> nbclient[version='>=0.5.0,<0.6.0'] -> nest-asyncio
# nest-asyncio
# nbclient -> nest-asyncio
#
# Package libsodium conflicts for:
# notebook -> pyzmq[version='>=17'] -> libsodium[version='>=1.0.18,<1.0.19.0a0']
# pyzmq -> libsodium[version='>=1.0.18,<1.0.19.0a0']
# zeromq -> libsodium[version='>=1.0.18,<1.0.19.0a0']
# jupyter_client -> pyzmq[version='>=13'] -> libsodium[version='>=1.0.18,<1.0.19.0a0']
# libsodium
#
# Package ipython conflicts for:
# jupyter_console -> ipykernel -> ipython[version='>=5.0']
# jupyter -> ipykernel -> ipython[version='>=4.0.0|>=5.0']
# ipywidgets -> ipykernel[version='>=4.5.1'] -> ipython[version='>=5.0']
# ipykernel -> ipython[version='>=5.0']
# qtconsole -> ipykernel[version='>=4.1'] -> ipython[version='>=5.0']
# jupyter_console -> ipython
# ipywidgets -> ipython[version='>=4.0.0']
# ipython
# notebook -> ipykernel -> ipython[version='>=5.0']
#
# Package mistune conflicts for:
# jupyter -> nbconvert -> mistune[version='>=0.8.1']
# notebook -> nbconvert -> mistune[version='>=0.8.1']
# mistune
# nbconvert -> mistune[version='>=0.8.1']
#
# Package pyparsing conflicts for:
# matplotlib -> matplotlib-base[version='>=3.3.3,<3.3.4.0a0'] -> pyparsing[version='>=2.0.3,!=2.0.4,!=2.1.2,!=2.1.6']
# matplotlib-base -> pyparsing[version='>=2.0.3,!=2.0.4,!=2.1.2,!=2.1.6']
# bleach -> packaging -> pyparsing[version='>=2.0.2']
# pyparsing
# packaging -> pyparsing[version='>=2.0.2']
#
# Package argon2-cffi conflicts for:
# jupyter -> notebook -> argon2-cffi
# widgetsnbextension -> notebook[version='>=4.4.1'] -> argon2-cffi
# notebook -> argon2-cffi
# argon2-cffi
#
# Package libboost conflicts for:
# rdkit -> py-boost -> libboost[version='>=1.73.0,<1.73.1.0a0',build=h37e3b65_11]
# libboost
# deepchem-gpu -> rdkit -> libboost[version='>=1.73.0,<1.74.0a0']
# py-boost -> libboost[version='>=1.73.0,<1.73.1.0a0',build=h37e3b65_11]
# rdkit -> libboost[version='>=1.73.0,<1.74.0a0']
#
# Package pycosat conflicts for:
# conda==4.9.2=py38h06a4308_0 -> pycosat[version='>=0.6.3']
# pycosat==0.6.3=py38h7b6447c_1
#
# Package pickleshare conflicts for:
# ipywidgets -> ipython[version='>=4.0.0'] -> pickleshare
# ipykernel -> ipython[version='>=5.0'] -> pickleshare
# jupyter_console -> ipython -> pickleshare
# pickleshare
# ipython -> pickleshare
#
# Package pthread-stubs conflicts for:
# pthread-stubs
# qt -> libxcb[version='>=1.13,<2.0a0'] -> pthread-stubs
# cairo -> libxcb -> pthread-stubs
# xorg-libx11 -> libxcb=1 -> pthread-stubs
# libxcb -> pthread-stubs
# gst-plugins-base -> libxcb[version='>=1.13,<2.0a0'] -> pthread-stubs
#
# Package notebook conflicts for:
# deepchem-gpu -> jupyter -> notebook
# jupyter -> notebook
# ipywidgets -> widgetsnbextension[version='>=3.5.0,<3.6.0'] -> notebook[version='>=4.4.1']
# notebook
# widgetsnbextension -> notebook[version='>=4.4.1']
#
# Package pyopenssl conflicts for:
# urllib3==1.25.11=py_0 -> pyopenssl[version='>=0.14']
# conda==4.9.2=py38h06a4308_0 -> pyopenssl[version='>=16.2.0']
# requests==2.24.0=py_0 -> urllib3[version='>=1.21.1,<1.26,!=1.25.0,!=1.25.1'] -> pyopenssl[version='>=0.14']
# pyopenssl==19.1.0=pyhd3eb1b0_1
#
# Package lcms2 conflicts for:
# matplotlib-base -> pillow[version='>=6.2.0'] -> lcms2[version='>=2.11,<3.0a0']
# lcms2
# pillow -> lcms2[version='>=2.11,<3.0a0']
# rdkit -> pillow -> lcms2[version='>=2.11,<3.0a0']
# deepchem-gpu -> pillow -> lcms2[version='>=2.11,<3.0a0']
#
# Package cairo conflicts for:
# cairo
# rdkit -> cairo[version='>=1.14.12,<2.0a0']
# deepchem-gpu -> rdkit -> cairo[version='>=1.14.12,<2.0a0']
#
# Package pandocfilters conflicts for:
# notebook -> nbconvert -> pandocfilters[version='>=1.4.1']
# jupyter -> nbconvert -> pandocfilters[version='>=1.4.1']
# pandocfilters
# nbconvert -> pandocfilters[version='>=1.4.1']
#
# Package h5py conflicts for:
# h5py
# keras-applications -> h5py
# tensorflow-base -> keras-applications[version='>=1.0.6'] -> h5py
#
# Package entrypoints conflicts for:
# entrypoints
# jupyter -> nbconvert -> entrypoints[version='>=0.2.2']
# notebook -> nbconvert -> entrypoints[version='>=0.2.2']
# nbconvert -> entrypoints[version='>=0.2.2']
#
# Package pytables conflicts for:
# pytables
# deepchem-gpu -> mdtraj -> pytables
# mdtraj -> pytables
#
# Package pyrsistent conflicts for:
# pyrsistent
# jsonschema -> pyrsistent[version='>=0.14.0']
# nbformat -> jsonschema[version='>=2.4,!=2.5.0'] -> pyrsistent[version='>=0.14.0']
#
# Package backcall conflicts for:
# ipython -> backcall
# backcall
# ipywidgets -> ipython[version='>=4.0.0'] -> backcall
# ipykernel -> ipython[version='>=5.0'] -> backcall
# jupyter_console -> ipython -> backcall
#
# Package brotlipy conflicts for:
# requests==2.24.0=py_0 -> urllib3[version='>=1.21.1,<1.26,!=1.25.0,!=1.25.1'] -> brotlipy[version='>=0.6.0']
# brotlipy==0.7.0=py38h27cfd23_1003
# urllib3==1.25.11=py_0 -> brotlipy[version='>=0.6.0']
#
# Package prompt_toolkit conflicts for:
# jupyter -> jupyter_console -> prompt_toolkit[version='>=2.0.0,<3.1.0,!=3.0.0,!=3.0.1']
# jupyter_console -> prompt_toolkit[version='>=2.0.0,<3.1.0,!=3.0.0,!=3.0.1']
# prompt_toolkit
#
# Package gstreamer conflicts for:
# gstreamer
# qt -> gst-plugins-base[version='>=1.14.0,<1.15.0a0'] -> gstreamer[version='>=1.14.0,<2.0a0']
# gst-plugins-base -> gstreamer[version='>=1.14.0,<2.0a0']
# qt -> gstreamer[version='>=1.14.0,<1.15.0a0']
# pyqt -> qt=5.9 -> gstreamer[version='>=1.14.0,<1.15.0a0']
#
# Package libnghttp2 conflicts for:
# libnghttp2
# tensorflow-base -> libcurl[version='>=7.71.1,<8.0a0'] -> libnghttp2[version='>=1.41.0,<2.0a0']
# hdf5 -> libcurl[version='>=7.71.1,<8.0a0'] -> libnghttp2[version='>=1.41.0,<2.0a0']
# libcurl -> libnghttp2[version='>=1.41.0,<2.0a0']
# tensorflow -> libcurl[version='>=7.71.1,<8.0a0'] -> libnghttp2[version='>=1.41.0,<2.0a0']
#
# Package attrs conflicts for:
# nbformat -> jsonschema[version='>=2.4,!=2.5.0'] -> attrs[version='>=17.4.0']
# jsonschema -> attrs[version='>=17.4.0']
# attrs
#
# Package pixman conflicts for:
# cairo -> pixman[version='>=0.38.0,<0.39.0a0']
# pixman
# rdkit -> cairo[version='>=1.14.12,<2.0a0'] -> pixman[version='>=0.38.0,<0.39.0a0']
#
# Package tensorflow-estimator conflicts for:
# tensorflow-base -> tensorflow-estimator[version='>=1.14.0rc0,<1.15.0a0']
# tensorflow -> tensorflow-base==1.14.0=py36hc3e5e64_0 -> tensorflow-estimator[version='>=1.14.0rc0,<1.15.0a0']
# tensorflow-estimator
#
# Package libprotobuf conflicts for:
# tensorflow-base -> protobuf[version='>=3.6.1'] -> libprotobuf[version='3.13.0.1.*|>=3.13.0.1,<3.14.0a0']
# tensorboard -> protobuf[version='>=3.4.0'] -> libprotobuf[version='3.13.0.1.*|>=3.13.0.1,<3.14.0a0']
# tensorflow-estimator -> protobuf[version='>=3.6.1'] -> libprotobuf[version='3.13.0.1.*|>=3.13.0.1,<3.14.0a0']
# libprotobuf
#
# Package send2trash conflicts for:
# send2trash
# notebook -> send2trash
# widgetsnbextension -> notebook[version='>=4.4.1'] -> send2trash
# jupyter -> notebook -> send2trash
#
# Package xorg-kbproto conflicts for:
# cairo -> xorg-libx11 -> xorg-kbproto
# xorg-libxrender -> xorg-libx11=1.6 -> xorg-kbproto
# xorg-libxext -> xorg-libx11=1.6 -> xorg-kbproto
# xorg-libx11 -> xorg-kbproto
# xorg-kbproto
#
# Package blosc conflicts for:
# blosc
# pytables -> blosc[version='>=1.20.1,<2.0a0']
# mdtraj -> pytables -> blosc[version='>=1.20.1,<2.0a0']
#
# Package packaging conflicts for:
# packaging
# nbconvert -> bleach -> packaging
# bleach -> packaging
#
# Package jedi conflicts for:
# jedi
# ipywidgets -> ipython[version='>=4.0.0'] -> jedi[version='>=0.10']
# ipykernel -> ipython[version='>=5.0'] -> jedi[version='>=0.10']
# ipython -> jedi[version='>=0.10']
# jupyter_console -> ipython -> jedi[version='>=0.10']
#
# Package bleach conflicts for:
# notebook -> nbconvert -> bleach
# jupyter -> nbconvert -> bleach
# bleach
# nbconvert -> bleach
#
# Package async_generator conflicts for:
# nbclient -> async_generator
# async_generator
# nbconvert -> nbclient[version='>=0.5.0,<0.6.0'] -> async_generator
#
# Package mdtraj conflicts for:
# mdtraj
# deepchem-gpu -> mdtraj
#
# Package xorg-libxdmcp conflicts for:
# libxcb -> xorg-libxdmcp
# xorg-libxdmcp
# qt -> libxcb[version='>=1.13,<2.0a0'] -> xorg-libxdmcp
# gst-plugins-base -> libxcb[version='>=1.13,<2.0a0'] -> xorg-libxdmcp
# xorg-libx11 -> libxcb=1 -> xorg-libxdmcp
# cairo -> libxcb -> xorg-libxdmcp
#
# Package jupyterlab_widgets conflicts for:
# ipywidgets -> jupyterlab_widgets[version='>=1.0.0']
# jupyterlab_widgets
# jupyter -> ipywidgets -> jupyterlab_widgets[version='>=1.0.0']
#
# Package xorg-libxext conflicts for:
# rdkit -> cairo[version='>=1.14.12,<2.0a0'] -> xorg-libxext
# xorg-libxext
# cairo -> xorg-libxext
#
# Package wheel conflicts for:
# pip==20.2.4=py38h06a4308_0 -> wheel
# wheel==0.35.1=pyhd3eb1b0_0
#
# Package testpath conflicts for:
# jupyter -> nbconvert -> testpath
# testpath
# nbconvert -> testpath
# notebook -> nbconvert -> testpath
#
# Package tensorboard conflicts for:
# tensorboard
# tensorflow-base -> tensorboard[version='>=1.14.0,<1.15.0a0']
# tensorflow -> tensorflow-base==1.14.0=py36hc3e5e64_0 -> tensorboard[version='>=1.14.0,<1.15.0a0']
#
# Package pandas conflicts for:
# rdkit -> pandas
# pandas
# mdtraj -> pandas
# deepchem-gpu -> pandas
#
# Package backports.functools_lru_cache conflicts for:
# backports.functools_lru_cache
# prompt-toolkit -> wcwidth -> backports.functools_lru_cache
# wcwidth -> backports.functools_lru_cache
#
# Package tensorflow conflicts for:
# tensorflow-gpu -> tensorflow==1.14.0
# deepchem-gpu -> tensorflow-gpu==1.14.0 -> tensorflow==1.14.0
# tensorflow
#
# Package _py-xgboost-mutex conflicts for:
# xgboost -> py-xgboost==1.2.0=py36h9f0ad1d_0 -> _py-xgboost-mutex==2.0=cpu_0
# py-xgboost -> _py-xgboost-mutex==2.0=cpu_0
# _py-xgboost-mutex
#
# Package openmm conflicts for:
# deepchem-gpu -> pdbfixer -> openmm[version='>=7.4.0']
# openmm
# pdbfixer -> openmm[version='>=7.4.0']
#
# Package requests conflicts for:
# conda==4.9.2=py38h06a4308_0 -> requests[version='>=2.18.4,<3']
# requests==2.24.0=py_0
# deepchem-gpu -> requests
#
# Package lzo conflicts for:
# pytables -> lzo[version='>=2.10,<3.0a0']
# lzo
# mdtraj -> pytables -> lzo[version='>=2.10,<3.0a0']
#
# Package kiwisolver conflicts for:
# kiwisolver
# matplotlib -> matplotlib-base[version='>=3.3.3,<3.3.4.0a0'] -> kiwisolver[version='>=1.0.1']
# matplotlib-base -> kiwisolver[version='>=1.0.1']
#
# Package scikit-learn conflicts for:
# xgboost -> py-xgboost==1.2.0=py36h9f0ad1d_0 -> scikit-learn
# deepchem-gpu -> scikit-learn
# scikit-learn
# py-xgboost -> scikit-learn
#
# Package keras-preprocessing conflicts for:
# tensorflow -> tensorflow-base==1.14.0=py36hc3e5e64_0 -> keras-preprocessing[version='>=1.0.5']
# keras-preprocessing
# tensorflow-base -> keras-preprocessing[version='>=1.0.5']
#
# Package xgboost conflicts for:
# xgboost
# deepchem-gpu -> xgboost
#
# Package keras-applications conflicts for:
# keras-applications
# tensorflow -> tensorflow-base==1.14.0=py36hc3e5e64_0 -> keras-applications[version='>=1.0.6']
# tensorflow-base -> keras-applications[version='>=1.0.6']
#
# Package tqdm conflicts for:
# tqdm==4.51.0=pyhd3eb1b0_0
# conda-package-handling==1.7.2=py38h03888b9_0 -> tqdm
# conda==4.9.2=py38h06a4308_0 -> conda-package-handling[version='>=1.3.0'] -> tqdm
#
# Package xorg-libsm conflicts for:
# cairo -> xorg-libsm
# xorg-libsm
# rdkit -> cairo[version='>=1.14.12,<2.0a0'] -> xorg-libsm
#
# Package prometheus_client conflicts for:
# notebook -> prometheus_client
# prometheus_client
# jupyter -> notebook -> prometheus_client
# widgetsnbextension -> notebook[version='>=4.4.1'] -> prometheus_client
#
# Package qtpy conflicts for:
# qtpy
# qtconsole -> qtpy
# jupyter -> qtconsole -> qtpy
#
# Package simdna conflicts for:
# simdna
# deepchem-gpu -> simdna
#
# Package jupyter conflicts for:
# deepchem-gpu -> jupyter
# jupyter
#
# Package _tflow_select conflicts for:
# _tflow_select
# tensorflow-gpu -> _tflow_select==2.1.0=gpu
# deepchem-gpu -> tensorflow-gpu==1.14.0 -> _tflow_select==2.1.0=gpu
#
# Package conda-package-handling conflicts for:
# conda==4.9.2=py38h06a4308_0 -> conda-package-handling[version='>=1.3.0']
# conda-package-handling==1.7.2=py38h03888b9_0
#
# Package pyqt conflicts for:
# matplotlib -> pyqt
# pyqt
# simdna -> matplotlib -> pyqt
# jupyter -> qtconsole -> pyqt
# qtconsole -> pyqt
#
#
# real	1m30.388s
# user	1m49.692s
# sys	0m17.977s
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - deepchem-gpu=2.3.0
#     - python=3.6
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |      conda_forge           3 KB  conda-forge
#     _openmp_mutex-4.5          |            1_gnu          22 KB  conda-forge
#     ld_impl_linux-64-2.35.1    |       hea4e1c9_1         617 KB  conda-forge
#     libgcc-ng-9.3.0            |      h5dbcf3e_17         7.8 MB  conda-forge
#     libgomp-9.3.0              |      h5dbcf3e_17         378 KB  conda-forge
#     libstdcxx-ng-9.3.0         |      h2ae2ef3_17         4.0 MB  conda-forge
#     openssl-1.1.1i             |       h7f98852_0         2.1 MB  conda-forge
#     python-3.6.12              |hffdb5ce_0_cpython        38.4 MB  conda-forge
#     sqlite-3.34.0              |       h74cdb3f_0         1.4 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        54.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   _openmp_mutex      conda-forge/linux-64::_openmp_mutex-4.5-1_gnu
#   libgomp            conda-forge/linux-64::libgomp-9.3.0-h5dbcf3e_17
#
# The following packages will be UPDATED:
#
#   ld_impl_linux-64   pkgs/main::ld_impl_linux-64-2.33.1-h5~ --> conda-forge::ld_impl_linux-64-2.35.1-hea4e1c9_1
#   libgcc-ng           pkgs/main::libgcc-ng-9.1.0-hdf63c60_0 --> conda-forge::libgcc-ng-9.3.0-h5dbcf3e_17
#   libstdcxx-ng       pkgs/main::libstdcxx-ng-9.1.0-hdf63c6~ --> conda-forge::libstdcxx-ng-9.3.0-h2ae2ef3_17
#   openssl                                 1.1.1h-h516909a_0 --> 1.1.1i-h7f98852_0
#   sqlite                pkgs/main::sqlite-3.33.0-h62c20be_0 --> conda-forge::sqlite-3.34.0-h74cdb3f_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   _libgcc_mutex           pkgs/main::_libgcc_mutex-0.1-main --> conda-forge::_libgcc_mutex-0.1-conda_forge
#   python                pkgs/main::python-3.6.12-hcff3b4d_2 --> conda-forge::python-3.6.12-hffdb5ce_0_cpython
#
#
#
# Downloading and Extracting Packages
# _openmp_mutex-4.5    | 22 KB     | : 100% 1.0/1 [00:00<00:00,  6.21it/s]
# libstdcxx-ng-9.3.0   | 4.0 MB    | : 100% 1.0/1 [00:00<00:00,  1.32it/s]
# libgomp-9.3.0        | 378 KB    | : 100% 1.0/1 [00:00<00:00,  8.93it/s]
# libgcc-ng-9.3.0      | 7.8 MB    | : 100% 1.0/1 [00:01<00:00,  1.33s/it]
# _libgcc_mutex-0.1    | 3 KB      | : 100% 1.0/1 [00:00<00:00, 10.01it/s]
# ld_impl_linux-64-2.3 | 617 KB    | : 100% 1.0/1 [00:00<00:00,  4.70it/s]
# sqlite-3.34.0        | 1.4 MB    | : 100% 1.0/1 [00:00<00:00,  3.59it/s]
# python-3.6.12        | 38.4 MB   | : 100% 1.0/1 [00:05<00:00,  5.89s/it]
# openssl-1.1.1i       | 2.1 MB    | : 100% 1.0/1 [00:00<00:00,  2.46it/s]
# done
# done
# done

# %% [markdown]
# #Import Rdkit library

# %%
import sys
sys.path.append('/usr/local/lib/python3.6/site-packages/') 

from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import Descriptors
from rdkit.Chem import AllChem
from rdkit import DataStructs
import numpy as np

# %% [markdown]
# #Draw molecules fom SMILES

# %%
mol = Chem.MolFromSmiles('CNC')
mol

# %% [markdown]
# **Labelling of Atoms**

# %%
def label(mol):
  for i, at in enumerate(mol.GetAtoms()):
    lbl = str(i)
    at.SetProp('atomLabel', lbl)
  return mol

# %%
label(mol)

# %% [markdown]
# #Calculate Adjacency Matrix

# %%
A = Chem.GetAdjacencyMatrix(mol)
A
# Out:
# array([[0, 1, 0],
#        [1, 0, 1],
#        [0, 1, 0]], dtype=int32)

# %% [markdown]
# **Convert array into matrix**

# %%
A =np.asmatrix(A)
A
# Out:
# matrix([[0, 1, 0],
#         [1, 0, 1],
#         [0, 1, 0]], dtype=int32)

# %%
C = [1,0]
N = [0,1]
X = np.array([C, N, C])
X
# Out:
# array([[1, 0],
#        [0, 1],
#        [1, 0]])

# %% [markdown]
# **Mtrix Product**

# %%
A@X   #Matrix product
# Out:
# matrix([[0, 1],
#         [2, 0],
#         [0, 1]])

# %% [markdown]
# **Identity Matrix**

# %%
I = np.matrix(np.eye(A.shape[0]))
I
# Out:
# matrix([[1., 0., 0.],
#         [0., 1., 0.],
#         [0., 0., 1.]])

# %%
A_hat = A + I
A_hat
# Out:
# matrix([[1., 1., 0.],
#         [1., 1., 1.],
#         [0., 1., 1.]])

# %% [markdown]
# **Matrix Product**

# %%
A_hat@X
# Out:
# matrix([[1., 1.],
#         [2., 1.],
#         [1., 1.]])

# %%
A_hat
# Out:
# matrix([[1., 1., 0.],
#         [1., 1., 1.],
#         [0., 1., 1.]])

# %% [markdown]
# **Matrix Column Sum**

# %%
D_hat = np.array(np.sum(A_hat, axis=0))[0]
D_hat
# Out:
# array([2., 3., 2.])

# %% [markdown]
# **Diagonal Matrix**

# %%
D_hat = np.matrix(np.diag(D_hat))
D_hat
# Out:
# matrix([[2., 0., 0.],
#         [0., 3., 0.],
#         [0., 0., 2.]])

# %%
D_hat**-1 *A_hat * X
# Out:
# matrix([[0.5       , 0.5       ],
#         [0.66666667, 0.33333333],
#         [0.5       , 0.5       ]])

# %% [markdown]
# **Square root of inverse of Matrix**

# %%
D_hat_inv = np.sqrt(D_hat**-1)
D_hat_inv
# Out:
# matrix([[0.70710678, 0.        , 0.        ],
#         [0.        , 0.57735027, 0.        ],
#         [0.        , 0.        , 0.70710678]])

# %% [markdown]
# **Symmetric Normalization**

# %%
H = D_hat_inv * A_hat * D_hat_inv * X
H
# Out:
# matrix([[0.5       , 0.40824829],
#         [0.81649658, 0.33333333],
#         [0.5       , 0.40824829]])

# %% [markdown]
# **Generate Random Matrix**

# %%
W = 2*np.random.rand(2,5) - 1 #number ofdescriptors x number of filter 
W = np.asmatrix(W)
W
# Out:
# matrix([[ 0.73262733, -0.30650017, -0.28796672, -0.28462724, -0.76883786],
#         [-0.83610636, -0.86927796,  0.9733707 ,  0.18526772, -0.70120239]])

# %%
Z = H * W
Z
# Out:
# matrix([[ 0.02497467, -0.50813133,  0.25339356, -0.06667839, -0.67068361],
#         [ 0.31948559, -0.54001566,  0.08933306, -0.17064126, -0.86148761],
#         [ 0.02497467, -0.50813133,  0.25339356, -0.06667839, -0.67068361]])

# %% [markdown]
# **Relu Activation**

# %%
def relu(x):
  return maximum(0,x)

# %%
mol2 = Chem.MolFromSmiles('CNCN')
mol2

# %%
label(mol2)

# %%
A = Chem.GetAdjacencyMatrix(mol2)
A = np.asmatrix(A)

C = [1, 0]
N = [0, 1]
X = np.array([C, N, C, N])

H1 = A * X
print(H1)

H2 = A*H1
print(H2)
# Out:
# [[0 1]
#  [2 0]
#  [0 2]
#  [1 0]]
# [[2 0]
#  [0 3]
#  [3 0]
#  [0 2]]

# %% [markdown]
# -------------------------------
